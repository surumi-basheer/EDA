# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/content/diamonds.csv")
df
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 49995   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 49996   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 49997   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 49998   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 49999   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [50000 rows x 10 columns]

# %%
df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
df.tail()
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 49995   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 49996   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 49997   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 49998   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 49999   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 47595 entries, 0 to 49999
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    47595 non-null  float64
#  1   clarity  47595 non-null  int64
#  2   table    47595 non-null  float64
#  3   price    47595 non-null  int64
# dtypes: float64(2), int64(2)
# memory usage: 1.8 MB

# %% [markdown]
# ## Checking null values

# %%
df.isnull().sum()
# Out:
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# price      0
# x          0
# y          0
# z          0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(8239)

# %%
df.shape
# Out:
# (47595, 4)

# %%
df.drop_duplicates(inplace = True)

# %%
df.shape
# Out:
# (39356, 4)

# %%
plt.bar(df["cut"],df["carat"])
plt.show()

# %%
df
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 49995   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 49996   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 49997   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 49998   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 49999   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [49874 rows x 10 columns]

# %%
plt.bar(df["cut"],df["depth"])
plt.show()

# %%
sns.histplot(df["cut"])
plt.show()

# %%
sns.histplot(df["price"],kde=True)
plt.show()

# %%
df["price"].hist()
# Out:
# <Axes: >

# %%
df["carat"].hist()
# Out:
# <Axes: >

# %%
df
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 49995   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 49996   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 49997   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 49998   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 49999   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [49874 rows x 10 columns]

# %%
sns.countplot(data=df,x="cut",hue="clarity")
plt.show()

# %%
sns.countplot(data=df,x="clarity")
plt.show()

# %%
print(df["cut"].unique())
# Out:
# ['Ideal' 'Premium' 'Good' 'Very Good' 'Fair']

# %% [markdown]
# ## Replace

# %%
df["cut"].replace(['Fair', 'Good', 'Very Good', 'Premium', 'Ideal'],[0,1,2,3,4],inplace=True)
df
# Out:
# /tmp/ipython-input-2001148890.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["cut"].replace(['Fair', 'Good', 'Very Good', 'Premium', 'Ideal'],[0,1,2,3,4],inplace=True)
# /tmp/ipython-input-2001148890.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["cut"].replace(['Fair', 'Good', 'Very Good', 'Premium', 'Ideal'],[0,1,2,3,4],inplace=True)
#        carat  cut color clarity  depth  table  price     x     y     z
# 0       0.23    4     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    3     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23    1     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    3     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31    1     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...  ...   ...     ...    ...    ...    ...   ...   ...   ...
# 49995   0.72    4     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 49996   0.72    1     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 49997   0.70    2     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 49998   0.86    3     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 49999   0.75    4     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [49874 rows x 10 columns]

# %%
print(df["color"].unique())
# Out:
# ['E' 'I' 'J' 'H' 'F' 'G' 'D']

# %%
df["color"].replace(['E' ,'I', 'J', 'H', 'F', 'G', 'D'],[0,1,2,3,4,5,6],inplace=True)
df
# Out:
# /tmp/ipython-input-2699740451.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["color"].replace(['E' ,'I', 'J', 'H', 'F', 'G', 'D'],[0,1,2,3,4,5,6],inplace=True)
# /tmp/ipython-input-2699740451.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["color"].replace(['E' ,'I', 'J', 'H', 'F', 'G', 'D'],[0,1,2,3,4,5,6],inplace=True)
#        carat  cut  color clarity  depth  table  price     x     y     z
# 0       0.23    4      0     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    3      0     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23    1      0     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    3      1     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31    1      2     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...  ...    ...     ...    ...    ...    ...   ...   ...   ...
# 49995   0.72    4      6     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 49996   0.72    1      6     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 49997   0.70    2      6     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 49998   0.86    3      3     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 49999   0.75    4      6     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [49874 rows x 10 columns]

# %%
print(df["clarity"].unique())
# Out:
# ['SI2' 'SI1' 'VS1' 'VS2' 'VVS2' 'VVS1' 'I1' 'IF']

# %%
df["clarity"].replace(['I1', 'SI2', 'SI1', 'VS2', 'VS1', 'VVS2', 'VVS1', 'IF'],[0,1,2,3,4,5,6,7],inplace=True)
df
# Out:
# /tmp/ipython-input-1142186314.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["clarity"].replace(['I1', 'SI2', 'SI1', 'VS2', 'VS1', 'VVS2', 'VVS1', 'IF'],[0,1,2,3,4,5,6,7],inplace=True)
# /tmp/ipython-input-1142186314.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["clarity"].replace(['I1', 'SI2', 'SI1', 'VS2', 'VS1', 'VVS2', 'VVS1', 'IF'],[0,1,2,3,4,5,6,7],inplace=True)
#        carat  cut  color  clarity  depth  table  price     x     y     z
# 0       0.23    4      0        1   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    3      0        2   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23    1      0        4   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    3      1        3   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31    1      2        1   63.3   58.0    335  4.34  4.35  2.75
# ...      ...  ...    ...      ...    ...    ...    ...   ...   ...   ...
# 49995   0.72    4      6        2   60.8   57.0   2757  5.75  5.76  3.50
# 49996   0.72    1      6        2   63.1   55.0   2757  5.69  5.75  3.61
# 49997   0.70    2      6        2   62.8   60.0   2757  5.66  5.68  3.56
# 49998   0.86    3      3        1   61.0   58.0   2757  6.15  6.12  3.74
# 49999   0.75    4      6        1   62.2   55.0   2757  5.83  5.87  3.64
#
# [49874 rows x 10 columns]

# %% [markdown]
# ## correlation

# %%
corr_matrix = df.corr()
sns.heatmap(corr_matrix,annot=True,fmt = "0.1f",cmap = "coolwarm")
plt.title("Correlation Matrix")
plt.show()

# %%
df.drop(["x","y","z"],axis=1,inplace=True)

# %%
price_corr = df.corr()["price"]
price_corr = price_corr.drop("price")
sns.heatmap(price_corr.to_frame(),annot = True,fmt=".2f",cmap ="coolwarm",cbar=True,annot_kws = {"size":10})
plt.title("Correlation between price and other Features")
plt.show()

# %%
df.drop(["cut","color","depth"],axis =1,inplace=True)

# %%
df.boxplot()
# Out:
# <Axes: >

# %%
def remove_outliers_iqr(df,exclude_column):
  for col in df.columns:
    # skip the specified column
    if col ==exclude_column:
      continue
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    # filter the dataframe to remove rows with  outliers in each column
    df = df[(df[col] >=lower_bound) & (df[col] <=upper_bound)]
  return df

# specify the column to exclude
df_cleaned = remove_outliers_iqr(df, exclude_column="price")
df = df_cleaned

# %%
df.shape
# Out:
# (47595, 4)

# %%
df
# Out:
#        carat  clarity  table  price
# 0       0.23        1   55.0    326
# 1       0.21        2   61.0    326
# 3       0.29        3   58.0    334
# 4       0.31        1   58.0    335
# 5       0.24        5   57.0    336
# ...      ...      ...    ...    ...
# 49995   0.72        2   57.0   2757
# 49996   0.72        2   55.0   2757
# 49997   0.70        2   60.0   2757
# 49998   0.86        1   58.0   2757
# 49999   0.75        1   55.0   2757
#
# [47595 rows x 4 columns]

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler

# select the features that you want to scale
features = ["carat","clarity","table"]

# create a MinMaxScaler object
scaler = MinMaxScaler()

#fit the scaler to your data and transform it
scaled_data = scaler.fit_transform(df[features])

# createw a dataframe from scaled_data with the correct column names
scaled_df = pd.DataFrame(scaled_data,columns=features)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import accuracy_score
import pandas as pd

X = df[["carat","clarity","table"]]  # Features
y = df['price']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42) # You can adjust the test_size and random_state



# Train a baseline logistic regression model
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()
